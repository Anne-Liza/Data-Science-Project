# %% [markdown]
# #**Libraries**

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing data
dt = pd.read_csv("creditcard.csv")

# %%
dt.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dt.info()

#35742 rows and 31 columns
#no missing data entries
# datatypes include 30 floats and 1 integer
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267336 entries, 0 to 267335
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    267336 non-null  float64
#  1   V1      267336 non-null  float64
#  2   V2      267336 non-null  float64
#  3   V3      267336 non-null  float64
#  4   V4      267336 non-null  float64
#  5   V5      267335 non-null  float64
#  6   V6      267335 non-null  float64
#  7   V7      267335 non-null  float64
#  8   V8      267335 non-null  float64
#  9   V9      267335 non-null  float64
#  10  V10     267335 non-null  float64
#  11  V11     267335 non-null  float64
#  12  V12     267335 non-null  float64
#  13  V13     267335 non-null  float64
#  14  V14     267335 non-null  float64
#  15  V15     267335 non-null  float64
#  16  V16     267335 non-null  float64
#  17  V17     267335 non-null  float64
#  18  V18     267335 non-null  float64
#  19  V19     267335 non-null  float64
# ...

# %%
dt.describe()
# a further description of the data
# Out:
#                Time             V1             V2             V3  \
# count  267336.00000  267336.000000  267336.000000  267336.000000
# mean    90085.15133      -0.012892      -0.014209       0.047238
# std     45138.19955       1.959217       1.658912       1.510397
# min         0.00000     -56.407510     -72.715728     -33.680984
# 25%     52240.00000      -0.925302      -0.607368      -0.813503
# 50%     80483.00000       0.015880       0.059872       0.239541
# 75%    133459.00000       1.292526       0.788194       1.063099
# max    162728.00000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  267336.000000  267335.000000  267335.000000  267335.000000
# mean        0.010539      -0.018890       0.008262      -0.008312
# std         1.416393       1.369393       1.325422       1.221688
# min        -5.683171     -42.147898     -26.160506     -43.557242
# ...

# %% [markdown]
# #**Data Cleaning**

# %%
dt.isnull().sum()
# there are missing values
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
dt = dt.fillna(dt.mean())
#replacing the missing data with the mean

# %%
dt.isnull().sum()
# there are no missing values
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dt.duplicated().sum()
#there are 140 duplicates
# Out:
# 973

# %%
# dropping duplicates
dt=dt.drop_duplicates()

# %%
dt.duplicated().sum()
#there are 0 duplicates
# Out:
# 0

# %%
#finding outliers
q1=dt.quantile(0.25)
q3=dt.quantile(0.75)
iqr=q3-q1
threshold=1.5*iqr
outliers=dt[((dt<(q1-threshold))|(dt>(q1+threshold)))]
outliers.count()
# Out:
# Time          0
# V1         6642
# V2        28039
# V3        18949
# V4        26294
# V5        35112
# V6        40417
# V7        26669
# V8        50109
# V9        32198
# V10       35393
# V11       18214
# V12       33102
# V13       24758
# V14       36655
# V15       19812
# V16       31054
# V17       30897
# V18       31542
# V19       33058
# V20       45943
# V21       31240
# V22       18111
# V23       40562
# V24       19130
# V25       21869
# V26       39997
# V27       64134
# V28       55307
# Amount    48275
# Class       462
# dtype: int64

# %%
#visualisation of outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x='V1', data=dt)
plt.title('Boxplot for v1')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Amount', data=dt)
plt.title('Boxplot for Amount')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V3', data=dt)
plt.title('Boxplot for V3')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V4', data=dt)
plt.title('Boxplot for V4')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V8', data=dt)
plt.title('Boxplot for V8')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V28', data=dt)
plt.title('Boxplot for V28')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V17', data=dt)
plt.title('Boxplot for V17')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V8', data=dt)
plt.title('Boxplot for V8')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V9', data=dt)
plt.title('Boxplot for V9')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Class', data=dt)
plt.title('Boxplot for Class')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='V11', data=dt)
plt.title('Boxplot for V11')
plt.show()

# %% [markdown]
# #**Exploratory Data Analysis (EDA)**

# %% [markdown]
# **1. Univariate**

# %%
dt["Amount"].value_counts()
# Out:
# 1.000000      12604
# 1.980000       5504
# 0.890000       4387
# 9.990000       4345
# 15.000000      3132
#               ...
# 357.440000        1
# 577.800000        1
# 444.610000        1
# 646.260000        1
# 89.640661         1
# Name: Amount, Length: 32031, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['Amount'].dropna(), bins=30, kde=True)
plt.title('Distribution of Amount')
plt.xlabel('Amount')
plt.ylabel('Count')
plt.show()

# %%
dt["Class"].value_counts()
# Out:
# 0.000000    265901
# 1.000000       461
# 0.001796         1
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['Class'].dropna(), bins=30, kde=True)
plt.title('Distribution of Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
dt["V1"].value_counts()
# Out:
#  2.055797    77
#  1.245674    77
#  2.053311    62
#  1.302378    60
#  2.040211    46
#              ..
#  1.036364     1
# -1.639048     1
#  0.993430     1
# -0.890333     1
#  1.972115     1
# Name: V1, Length: 259084, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['V21'].dropna(), bins=30, kde=True)
plt.title('Distribution of V1')
plt.xlabel('V1')
plt.ylabel('Count')
plt.show()

# %%
dt["V8"].value_counts()
# Out:
#  0.727706    77
# -0.160211    77
# -0.207071    62
#  0.959147    60
#  0.784393    46
#              ..
#  0.110903     1
#  1.505155     1
#  0.233684     1
#  0.939042     1
# -0.000036     1
# Name: V8, Length: 259084, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['V8'].dropna(), bins=30, kde=True)
plt.title('Distribution of V8')
plt.xlabel('V8')
plt.ylabel('Count')
plt.show()

# %%
dt["V17"].value_counts()
# Out:
# -0.601957    77
# -0.374656    77
#  0.549365    62
# -0.651405    60
#  0.473898    46
#              ..
# -0.831839     1
#  3.267880     1
# -0.632100     1
#  1.186688     1
#  0.004706     1
# Name: V17, Length: 259084, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['V17'].dropna(), bins=30, kde=True)
plt.title('Distribution of V17')
plt.xlabel('V17')
plt.ylabel('Count')
plt.show()

# %%
dt["V28"].value_counts()
# Out:
# -0.060282    77
#  0.018495    77
# -0.029585    62
#  0.028697    60
# -0.042787    46
#              ..
#  0.028616     1
#  0.053365     1
#  0.035952     1
#  0.075166     1
#  0.000774     1
# Name: V28, Length: 259084, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dt['V28'].dropna(), bins=30, kde=True)
plt.title('Distribution of V28')
plt.xlabel('V28')
plt.ylabel('Count')
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(30, 20))
visuals = dt[['Amount', 'Class', 'V1', 'V8', 'V17', 'V28']]

for cols, ax in zip(visuals.columns, axes.flatten()):
    sns.histplot(dt[cols], ax=ax, bins=50, edgecolor='black', color='blue', alpha=0.5, linewidth=2)
    ax.set_title(cols)

plt.tight_layout()
plt.show()

# a loop diagram of the columns

# %% [markdown]
# **Bivariate**

# %%
fig, axes = plt.subplots(2, 2, figsize=(17, 10))
colors = sns.color_palette("pastel")[:3]  # Use the first three colors from the pastel palette
visuals = dt[['V1', 'V8', 'V17', 'V28']]

for col, ax in zip(visuals.columns, axes.flatten()):
    for Amount, color in zip(dt['Amount'].unique(), colors):
        sns.histplot(data=dt[dt['Amount'] == Amount], x=col, ax=ax, color=color, bins=20, edgecolor='black', alpha=0.7, linewidth=2, label=f'Amount {Amount}')
    ax.set_title(col)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Correlation Matrix**

# %%
correlation_mat = dt.corr()

# %%
#visualisation of correlation matrix using heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_mat, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #**MODELLING**

# %% [markdown]
# **Data Training**

# %%
# splitting data for training
x = dt.drop('Amount', axis = 1)
y = dt[['Amount']]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.3)

# %% [markdown]
# **Feature Importance**

# %%
y_train_categorical = (y_train > y_train.mean()).astype(int)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train_categorical, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
feature_importance = pd.Series(rfc.feature_importances_, x.columns).sort_values(ascending = False)
fig, axes = plt.subplots(figsize = (30,20))
sns.barplot(x=feature_importance, y=feature_importance.index, color='blue', alpha=0.5, edgecolor = 'black', linewidth = 2);

#for accurate prediction use V2,V20, V9,V5 and V1.

# %% [markdown]
# **Models**

# %% [markdown]
# **1. RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
print(classification_report(y_test, y_pred))

# this model has a 96% accuracy level
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     28837
#            1       0.98      0.82      0.89      8454
#
#     accuracy                           0.96     37291
#    macro avg       0.96      0.91      0.93     37291
# weighted avg       0.96      0.96      0.95     37291

# %% [markdown]
# **2. Logic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver='liblinear', random_state=0)
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)
print(classification_report(y_test, y_pred))

# this model has a 77% accuracy level
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87     28837
#            1       0.00      0.00      0.00      8454
#
#     accuracy                           0.77     37291
#    macro avg       0.39      0.50      0.44     37291
# weighted avg       0.60      0.77      0.67     37291
